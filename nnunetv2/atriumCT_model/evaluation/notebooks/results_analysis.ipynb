# %%
import pandas as pd

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
df = pd.read_csv('/media/sharedata/atriumCT/atrium_nnunet/raw_data/Dataset004_LA_CT00_corrected_voted/prediction_3d_dataset002/patients_history_final_metrics.csv', index_col=0)
df = df[(df['ID']!=46)&(df['ID']!=104)&(df['ID']!=11)]
df
# Out:
#              ID  Stroke_ait_history  peripheral_embolism_hist  embolism_hist  \
# Unnamed: 0
# 0             6                   1                         0              1
# 1             7                   1                         0              1
# 2             8                   0                         0              0
# 3             9                   1                         0              1
# 5            13                   0                         0              0
# 6            14                   1                         0              1
# 7            16                   0                         0              0
# 8            17                   0                         0              0
# 9            20                   0                         0              0
# 10           21                   1                         0              1
# 11           22                   1                         0              1
# ...

# %%
df_opa = df[df['LAA_opacification_defect']==1]
df_opa.shape
# Out:
# (54, 19)

# %%
df_no_opa = df[df['LAA_opacification_defect']==0]
df_no_opa.shape
# Out:
# (75, 19)

# %%
df_opa['Dice_auricle'].hist(bins=50, range=(0, 1))
# Out:
# <AxesSubplot:>

# %%
df_no_opa['Dice_auricle'].hist(bins=50, range=(0, 1))
# Out:
# <AxesSubplot:>

# %%
df_opa
# Out:
#              ID  Stroke_ait_history  peripheral_embolism_hist  embolism_hist  \
# Unnamed: 0
# 1             7                   1                         0              1
# 3             9                   1                         0              1
# 6            14                   1                         0              1
# 8            17                   0                         0              0
# 12           23                   0                         0              0
# 16           28                   1                         0              1
# 17           29                   0                         0              0
# 19           31                   0                         0              0
# 20           32                   0                         0              0
# 23           38                   0                         0              0
# 26           43                   1                         0              1
# ...

# %%
df_opa[df_opa['Dice_auricle']>0.95]
# Out:
#              ID  Stroke_ait_history  peripheral_embolism_hist  embolism_hist  \
# Unnamed: 0
# 3             9                   1                         0              1
# 23           38                   0                         0              0
# 94          238                   1                         0              1
#
#             verified_thrombus  LAA_opacification_defect      Dice       IoU  \
# Unnamed: 0
# 3                           0                         1  0.980152  0.961077
# 23                          1                         1  0.933602  0.875472
# 94                          0                         1  0.946182  0.897861
#
#             nnUnet_id  Contour_Volume  Dice_auricle  Dice_corps  Dice_RSPV_1  \
# Unnamed: 0
# 3                   3         12770.0      0.990106    0.995420     0.887257
# 23                 24         38512.0      0.999215    0.999102     0.921313
# 94                 94        369062.0      0.995475    0.999935     0.827098
#
# ...

# %% [markdown]
# On peut voir que dans les cas où la dice de l'auricule est très élevée, si la dice globale est plus faible, c'est à cause de la dice sur les veines.

# %%
df['Dice_corps'].hist(bins=50, range=(0, 1))
# Out:
# <AxesSubplot:>

# %%
df[['Dice', 'Dice_corps', 'Dice_auricle', 'Dice_RSPV_1', 'Dice_RIPV_2', 'Dice_LIPV_3', 'Dice_LSPV_4']].mean()
# Out:
# Dice            0.938445
# Dice_corps      0.997504
# Dice_auricle    0.893700
# Dice_RSPV_1     0.867201
# Dice_RIPV_2     0.849923
# Dice_LIPV_3     0.791409
# Dice_LSPV_4     0.783762
# dtype: float64

# %% [markdown]
# D'après ces moyennes, on remarque que la dice globale est fortement impactée par les dices des veines qui ne sont pas très élevées. Ce qui correspond au résultat attendu car la découpe des veines pèse dans le calcul de la dice.
